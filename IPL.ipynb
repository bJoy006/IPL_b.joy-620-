# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("/content/data (1).csv")
print(df)
# Out:
#       id  season        city        date                  team1  \
# 0      1    2008   Bangalore  2008-04-18  Kolkata Knight Riders
# 1      2    2008  Chandigarh  2008-04-19    Chennai Super Kings
# 2      3    2008       Delhi  2008-04-19       Rajasthan Royals
# 3      4    2008      Mumbai  2008-04-20         Mumbai Indians
# 4      5    2008     Kolkata  2008-04-20        Deccan Chargers
# ..   ...     ...         ...         ...                    ...
# 572  573    2016      Raipur  2016-05-22       Delhi Daredevils
# 573  574    2016   Bangalore  2016-05-24          Gujarat Lions
# 574  575    2016       Delhi  2016-05-25    Sunrisers Hyderabad
# 575  576    2016       Delhi  2016-05-27          Gujarat Lions
# 576  577    2016   Bangalore  2016-05-29    Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# 0    Royal Challengers Bangalore  Royal Challengers Bangalore         field
# ...

# %%
df[0:577]
# Out:
#       id  season        city        date                  team1  \
# 0      1    2008   Bangalore  2008-04-18  Kolkata Knight Riders
# 1      2    2008  Chandigarh  2008-04-19    Chennai Super Kings
# 2      3    2008       Delhi  2008-04-19       Rajasthan Royals
# 3      4    2008      Mumbai  2008-04-20         Mumbai Indians
# 4      5    2008     Kolkata  2008-04-20        Deccan Chargers
# ..   ...     ...         ...         ...                    ...
# 572  573    2016      Raipur  2016-05-22       Delhi Daredevils
# 573  574    2016   Bangalore  2016-05-24          Gujarat Lions
# 574  575    2016       Delhi  2016-05-25    Sunrisers Hyderabad
# 575  576    2016       Delhi  2016-05-27          Gujarat Lions
# 576  577    2016   Bangalore  2016-05-29    Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# 0    Royal Challengers Bangalore  Royal Challengers Bangalore         field
# ...

# %% [markdown]
# Applying data analysis

# %%
df.shape
# Out:
# (577, 18)

# %%
df.columns
# Out:
# Index(['id', 'season', 'city', 'date', 'team1', 'team2', 'toss_winner',
#        'toss_decision', 'result', 'dl_applied', 'winner', 'win_by_runs',
#        'win_by_wickets', 'player_of_match', 'venue', 'umpire1', 'umpire2',
#        'umpire3'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 577 entries, 0 to 576
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               577 non-null    int64
#  1   season           577 non-null    int64
#  2   city             570 non-null    object
#  3   date             577 non-null    object
#  4   team1            577 non-null    object
#  5   team2            577 non-null    object
#  6   toss_winner      577 non-null    object
#  7   toss_decision    577 non-null    object
#  8   result           577 non-null    object
#  9   dl_applied       577 non-null    int64
#  10  winner           574 non-null    object
#  11  win_by_runs      577 non-null    int64
#  12  win_by_wickets   577 non-null    int64
#  13  player_of_match  574 non-null    object
#  14  venue            577 non-null    object
#  15  umpire1          577 non-null    object
#  16  umpire2          577 non-null    object
# ...

# %%
df.describe()
# Out:
#                id       season  dl_applied  win_by_runs  win_by_wickets  \
# count  577.000000   577.000000  577.000000   577.000000      577.000000
# mean   289.000000  2012.029463    0.025997    13.715771        3.363951
# std    166.709828     2.486247    0.159263    23.619282        3.416049
# min      1.000000  2008.000000    0.000000     0.000000        0.000000
# 25%    145.000000  2010.000000    0.000000     0.000000        0.000000
# 50%    289.000000  2012.000000    0.000000     0.000000        3.000000
# 75%    433.000000  2014.000000    0.000000    20.000000        6.000000
# max    577.000000  2016.000000    1.000000   144.000000       10.000000
#
#        umpire3
# count      0.0
# mean       NaN
# std        NaN
# min        NaN
# 25%        NaN
# 50%        NaN
# 75%        NaN
# max        NaN

# %%
df["win_by_runs"].value_counts()
# Out:
# win_by_runs
# 0      316
# 23       9
# 10       8
# 24       8
# 9        8
#       ...
# 53       1
# 75       1
# 105      1
# 66       1
# 80       1
# Name: count, Length: 83, dtype: int64

# %%
df.dtypes.value_counts()
# Out:
# object     12
# int64       5
# float64     1
# Name: count, dtype: int64

# %% [markdown]
# Missing_values

# %%
df.isnull().sum()
# Out:
# id                   0
# season               0
# city                 7
# date                 0
# team1                0
# team2                0
# toss_winner          0
# toss_decision        0
# result               0
# dl_applied           0
# winner               3
# win_by_runs          0
# win_by_wickets       0
# player_of_match      3
# venue                0
# umpire1              0
# umpire2              0
# umpire3            577
# dtype: int64

# %%
df["umpire3_ipl"]=np.where(df["umpire3"].isnull(),1,0)
df["umpire3_ipl"][0:577]
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 572    1
# 573    1
# 574    1
# 575    1
# 576    1
# Name: umpire3_ipl, Length: 577, dtype: int64

# %%
df["umpire3"].fillna(df["umpire3"].mean(), inplace=True)
df.isnull().sum()
# Out:
# id                   0
# season               0
# city                 7
# date                 0
# team1                0
# team2                0
# toss_winner          0
# toss_decision        0
# result               0
# dl_applied           0
# winner               3
# win_by_runs          0
# win_by_wickets       0
# player_of_match      3
# venue                0
# umpire1              0
# umpire2              0
# umpire3            577
# dtype: int64

# %%
df.umpire3.isnull().sum()
# Out:
# 577

# %%
df[0:577]
# Out:
#       id  season        city        date                  team1  \
# 0      1    2008   Bangalore  2008-04-18  Kolkata Knight Riders
# 1      2    2008  Chandigarh  2008-04-19    Chennai Super Kings
# 2      3    2008       Delhi  2008-04-19       Rajasthan Royals
# 3      4    2008      Mumbai  2008-04-20         Mumbai Indians
# 4      5    2008     Kolkata  2008-04-20        Deccan Chargers
# ..   ...     ...         ...         ...                    ...
# 572  573    2016      Raipur  2016-05-22       Delhi Daredevils
# 573  574    2016   Bangalore  2016-05-24          Gujarat Lions
# 574  575    2016       Delhi  2016-05-25    Sunrisers Hyderabad
# 575  576    2016       Delhi  2016-05-27          Gujarat Lions
# 576  577    2016   Bangalore  2016-05-29    Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# 0    Royal Challengers Bangalore  Royal Challengers Bangalore         field
# ...

# %%
season=df["season"]
plt.plot(season)
plt.show()

# %%
season=df["season"]
plt.plot(season,color='green',label='season') # Changed 'lebel'
plt.legend()
plt.show()

# %%
sns.boxplot(df['winner'])
# Out:
# <Axes: ylabel='winner'>

# %%
sns.scatterplot(x='season',y='winner',data=df)
# Out:
# <Axes: xlabel='season', ylabel='winner'>

# %%
sns.histplot(x='season',data=df)
# Out:
# <Axes: xlabel='season', ylabel='Count'>

# %%
sns.barplot(x='toss_decision',y="toss_winner",data=df)
# Out:
# <Axes: xlabel='toss_decision', ylabel='toss_winner'>

# %%
sns.jointplot(x='win_by_runs',y='win_by_wickets',data=df)

# %%
sns.pairplot(df,hue="winner")

# %%
sns.pairplot(df,hue="winner",palette="Blues")

# %%
sns.countplot(x="winner",hue="city",data=df)
# Out:
# <Axes: xlabel='winner', ylabel='count'>

# %%
sns.distplot(x="season",data=df)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-78-47931a9261ea> in <cell line: 1>()
# ----> 1 sns.distplot(x="season",data=df)
#
# TypeError: distplot() got an unexpected keyword argument 'data'

# %%
corr_ipl=df[["dl_applied","win_by_runs","win_by_wickets"]].corr()
print(corr_ipl)
sns.heatmap(corr_ipl)
# Out:
#                 dl_applied  win_by_runs  win_by_wickets
# dl_applied        1.000000    -0.005878       -0.023803
# win_by_runs      -0.005878     1.000000       -0.572839
# win_by_wickets   -0.023803    -0.572839        1.000000
# <Axes: >
